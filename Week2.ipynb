# %% [markdown]
# <a href="https://colab.research.google.com/github/lenkaflorienkaa/pcvkganjil_2024/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing my google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/kitten.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
import cv2
import matplotlib.pyplot as plt

img_gray = cv2.imread('/content/drive/MyDrive/PCVK/kitten.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap='gray')
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

img_gray = cv2.imread('/content/drive/MyDrive/PCVK/kitten.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap='magma')
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('/content/drive/MyDrive/PCVK/kitten.jpg')

img4 = cv2.resize(cv2.cvtColor(img, cv2.COLOR_BGR2RGB), (512, 1024))

plt.imshow(img4)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('/content/drive/MyDrive/PCVK/kitten.jpg')

img5 = cv2.flip(cv2.cvtColor(img, cv2.COLOR_BGR2RGB), 0)

# Save the flipped image to a file (uncomment to use)
# cv2.imwrite('/content/drive/MyDrive/PCVK_MM/Images/mandrill2.tiff', img5)

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.imshow(img5)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

black_img = np.zeros(shape=(512, 512, 3), dtype=np.int16)

plt.imshow(black_img)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

black_img = np.zeros(shape=(512, 512, 3), dtype=np.int16)

cv2.rectangle(black_img, pt1=(384, 0), pt2=(510, 150), color=(0, 255, 0), thickness=10)

plt.imshow(black_img)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

black_img = np.zeros(shape=(512, 512, 3), dtype=np.int16)

cv2.rectangle(black_img, pt1=(384, 0), pt2=(510, 150), color=(0, 255, 0), thickness=10)

cv2.rectangle(black_img, pt1=(200, 200), pt2=(300, 300), color=(0, 0, 255), thickness=15)

plt.imshow(black_img)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

black_img = np.zeros(shape=(512, 512, 3), dtype=np.int16)

cv2.rectangle(black_img, pt1=(384, 0), pt2=(510, 150), color=(0, 255, 0), thickness=10)

cv2.rectangle(black_img, pt1=(200, 200), pt2=(300, 300), color=(0, 0, 255), thickness=15)

cv2.circle(black_img, center=(100, 100), radius=50, color=(255, 0, 0), thickness=8)

plt.imshow(black_img)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

black_img = np.zeros(shape=(512, 512, 3), dtype=np.int16)

cv2.rectangle(black_img, pt1=(384, 0), pt2=(510, 150), color=(0, 255, 0), thickness=10)

cv2.rectangle(black_img, pt1=(200, 200), pt2=(300, 300), color=(0, 0, 255), thickness=15)

cv2.circle(black_img, center=(100, 100), radius=50, color=(255, 0, 0), thickness=8)

cv2.line(black_img, pt1=(0, 0), pt2=(512, 512), color=(255, 255, 255), thickness=5)

plt.imshow(black_img)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

black_img = np.zeros(shape=(512, 512, 3), dtype=np.int16)

cv2.rectangle(black_img, pt1=(384, 0), pt2=(510, 150), color=(0, 255, 0), thickness=10)

cv2.rectangle(black_img, pt1=(200, 200), pt2=(300, 300), color=(0, 0, 255), thickness=15)

cv2.circle(black_img, center=(100, 100), radius=50, color=(255, 0, 0), thickness=8)

cv2.line(black_img, pt1=(0, 0), pt2=(512, 512), color=(255, 255, 255), thickness=5)

font = cv2.FONT_HERSHEY_SIMPLEX

cv2.putText(black_img, text="Hello", org=(10, 500), fontFace=font, fontScale=4, color=(255, 255, 0), thickness=2, lineType=cv2.LINE_AA)

plt.imshow(black_img)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

black_img2 = np.zeros(shape=(512, 512, 3), dtype=np.int32)

plt.imshow(black_img2)
plt.show()

# %%
vertices = np.array([[100,300], [200,200], [400,300], [200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
import cv2
import matplotlib.pyplot as plt
cv2.polylines(black_img2, [pts], isClosed=True, color=(255, 0, 0), thickness=5)

plt.imshow(black_img2)
